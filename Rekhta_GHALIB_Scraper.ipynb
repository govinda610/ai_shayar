# %%
# !pip install beautifulsoup4
# !pip install selenium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 KB 3.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.0/359.0 KB 5.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 KB 1.6 MB/s eta 0:00:00
# ...

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
  
#url of the page we want to scrape
url = "https://www.rekhta.org/poets/mirza-ghalib/couplets"
url1 = "https://www.rekhta.org/PoetCollection?SEO_Slug=couplets&Id=c5097803-df0b-44eb-91fc-b20413837614&lang=1&pageNumber=2&Info=sher&StartsWith=a&typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&sort=popularity-desc&_=1653747573736"
url2 = "https://www.rekhta.org/PoetCollection?SEO_Slug=couplets&Id=c5097803-df0b-44eb-91fc-b20413837614&lang=1&pageNumber=3&Info=sher&StartsWith=a&typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&sort=popularity-desc&_=1653747573737"
url3 = "https://www.rekhta.org/PoetCollection?SEO_Slug=couplets&Id=c5097803-df0b-44eb-91fc-b20413837614&lang=1&pageNumber=4&Info=sher&StartsWith=a&typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&sort=popularity-desc&_=1653747573738"
url4 = "https://www.rekhta.org/PoetCollection?SEO_Slug=couplets&Id=c5097803-df0b-44eb-91fc-b20413837614&lang=1&pageNumber=5&Info=sher&StartsWith=a&typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&sort=popularity-desc&_=1653747573739"
url5 = "https://www.rekhta.org/PoetCollection?SEO_Slug=couplets&Id=c5097803-df0b-44eb-91fc-b20413837614&lang=1&pageNumber=6&Info=sher&StartsWith=a&typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&sort=popularity-desc&_=1653747573740"
url6 = "https://www.rekhta.org/PoetCollection?SEO_Slug=couplets&Id=c5097803-df0b-44eb-91fc-b20413837614&lang=1&pageNumber=7&Info=sher&StartsWith=a&typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&sort=popularity-desc&_=1653747573741"
url7 = "https://www.rekhta.org/PoetCollection?SEO_Slug=couplets&Id=c5097803-df0b-44eb-91fc-b20413837614&lang=1&pageNumber=8&Info=sher&StartsWith=a&typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&sort=popularity-desc&_=1653747573742"
# initiating the webdriver. Parameter includes the path of the webdriver.
driver = webdriver.Chrome('/Users/govindmittal/Downloads/chromedriver') 


driver.get(url) 
time.sleep(5) 
  
html = driver.page_source
driver.get(url1)
html1 = driver.page_source
driver.get(url2)
html2 = driver.page_source
driver.get(url3)
html3 = driver.page_source
driver.get(url4)
html4 = driver.page_source
driver.get(url5)
html5 = driver.page_source
driver.get(url6)
html6 = driver.page_source
driver.get(url7)
html7 = driver.page_source

  
# this renders the JS code and stores all
# of the information in static HTML code.
  
# Now, we could simply apply bs4 to html variable
soup = BeautifulSoup(html, "html.parser")
soup1 = BeautifulSoup(html1, "html.parser")
soup2 = BeautifulSoup(html2, "html.parser")
soup3 = BeautifulSoup(html3, "html.parser")
soup4 = BeautifulSoup(html4, "html.parser")
soup5 = BeautifulSoup(html5, "html.parser")
soup6 = BeautifulSoup(html6, "html.parser")
soup7 = BeautifulSoup(html7, "html.parser")
# Out:
# /var/folders/8w/h9y580gd7y55yx6l03k76n5c0000gn/T/ipykernel_7029/3053561204.py:17: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/govindmittal/Downloads/chromedriver')

# %%
# We can use the requests library directly rather than using selenium to open a browser

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
page = requests.get("https://www.rekhta.org/poets/mirza-ghalib/couplets")
print(page)
soupv2 = BeautifulSoup(page.text, "html.parser")
divs = soupv2.find_all("div",{"class" : "c"}) 
divs[1].text
# Out:
# <Response [200]>
# "hum ko malum hai jannat ki haqiqat lekin dil ke KHush rakhne ko 'ghaalib' ye KHayal achchha hai "

# %%
urls = soupv2.find_all("div",{"class" : "contentLoadMorePaging"})
urls[0]
# Out:
# <div class="contentLoadMorePaging" data-url="/PoetCollection?SEO_Slug=couplets&amp;Id=c5097803-df0b-44eb-91fc-b20413837614&amp;lang=1&amp;pageNumber=2&amp;Info=sher&amp;StartsWith=a&amp;typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&amp;sort=popularity-desc">
# <svg class="screenLoader" height="50px" viewbox="0 0 80 80" width="50px"><circle class="path" cx="40" cy="40" fill="none" r="30" stroke-linecap="square" stroke-width="5"></circle></svg>
# </div>

# %%
SCROLL_PAUSE_TIME = 3
url = "https://www.rekhta.org/poets/mirza-ghalib/couplets"
driver = webdriver.Chrome('/Users/govindmittal/Downloads/chromedriver') 
driver.get(url) 
time.sleep(5) 

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

ghazals = driver.find_elements_by_class_name("c")

for ghazal in ghazals:
    print(ghazal.text)
# Out:
# /var/folders/8w/h9y580gd7y55yx6l03k76n5c0000gn/T/ipykernel_1558/2764192189.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/govindmittal/Downloads/chromedriver')
# /var/folders/8w/h9y580gd7y55yx6l03k76n5c0000gn/T/ipykernel_1558/2764192189.py:23: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   ghazals = driver.find_elements_by_class_name("c")
# ham ko ma.alūm hai jannat kī haqīqat lekin
# dil ke ḳhush rakhne ko 'ġhālib' ye ḳhayāl achchhā hai
#
# ishq ne 'ġhālib' nikammā kar diyā
# varna ham bhī aadmī the kaam ke
#
# is sādgī pe kaun na mar jaa.e ai ḳhudā
# laḌte haiñ aur haath meñ talvār bhī nahīñ
#
# mohabbat meñ nahīñ hai farq jiine aur marne kā
# usī ko dekh kar jiite haiñ jis kāfir pe dam nikle
#
# hazāroñ ḳhvāhisheñ aisī ki har ḳhvāhish pe dam nikle
# bahut nikle mire armān lekin phir bhī kam nikle
#
# ...

# %%
ghalibshers = []
for ghazal in ghazals:
    ghalibshers.append(ghazal.text)
ghalibshers
# Out:
# ["ham ko ma.alūm hai jannat kī haqīqat lekin \ndil ke ḳhush rakhne ko 'ġhālib' ye ḳhayāl achchhā hai ",
#  '',
#  "ishq ne 'ġhālib' nikammā kar diyā \nvarna ham bhī aadmī the kaam ke ",
#  '',
#  'is sādgī pe kaun na mar jaa.e ai ḳhudā \nlaḌte haiñ aur haath meñ talvār bhī nahīñ ',
#  '',
#  'mohabbat meñ nahīñ hai farq jiine aur marne kā \nusī ko dekh kar jiite haiñ jis kāfir pe dam nikle ',
#  '',
#  'hazāroñ ḳhvāhisheñ aisī ki har ḳhvāhish pe dam nikle \nbahut nikle mire armān lekin phir bhī kam nikle ',
#  '',
#  'un ke dekhe se jo aa jaatī hai muñh par raunaq \nvo samajhte haiñ ki bīmār kā haal achchhā hai ',
#  '',
#  'ye na thī hamārī qismat ki visāl-e-yār hotā \nagar aur jiite rahte yahī intizār hotā ',
#  '',
#  'ragoñ meñ dauḌte phirne ke ham nahīñ qaa.il \njab aañkh hī se na Tapkā to phir lahū kyā hai ',
#  '',
#  'ishrat-e-qatra hai dariyā meñ fanā ho jaanā \ndard kā had se guzarnā hai davā ho jaanā ',
#  '',
# ...

# %%
ghazals[4].text
# Out:
# 'is sādgī pe kaun na mar jaa.e ai ḳhudā \nlaḌte haiñ aur haath meñ talvār bhī nahīñ '

# %%
soupv2
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="notranslate" name="google"/>
# <meta content="width=device-width, minimum-scale=1.0" name="viewport"/>
# <link href="https://rekhta.pc.cdn.bitgravity.com/content/images/favico.png" rel="icon" type="image/png"/>
# <meta content="Rekhta" property="og:site_name"/>
# <meta content="710470395652694" property="fb:app_id"/>
# <meta content="@Rekhta" name="twitter:site"/>
# <meta content="@Rekhta" name="twitter:creator"/>
# <title>Shayari of Mirza Ghalib | Rekhta</title>
# <meta content="Mirza Ghalib Shayari available in Hindi, Urdu and Roman scripts. Access to poetry videos, audios &amp; Ebooks of Mirza Ghalib." name="description"/>
# <link href="https://www.rekhta.org/poets/mirza-ghalib/couplets" rel="canonical"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://www.rekhta.org/poets/mirza-ghalib/couplets" name="twitter:url"/>
# <meta content="Shayari of Mirza Ghalib | Rekhta" name="twitter:title"/>
# ...

# %%
print(soup.prettify)

# %%
soups = [soup,soup1,soup2,soup3,soup4,soup5,soup6,soup7]

# %%
#print(soup1.prettify)

# %%
print(data)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
#soups[0]

# %%
df = []
for i in soups:
    for k in i.find_all('div', {'class' : 'c'}):
        print(k.text)
        result = k.text
        df.append(result)
# Out:
# ham ko ma.alūm hai jannat kī haqīqat lekin dil ke ḳhush rakhne ko 'ġhālib' ye ḳhayāl achchhā hai
# hum ko malum hai jannat ki haqiqat lekin dil ke KHush rakhne ko 'ghaalib' ye KHayal achchha hai
# ishq ne 'ġhālib' nikammā kar diyā varna ham bhī aadmī the kaam ke
# ishq ne 'ghaalib' nikamma kar diya warna hum bhi aadmi the kaam ke
# is sādgī pe kaun na mar jaa.e ai ḳhudā laḌte haiñ aur haath meñ talvār bhī nahīñ
# is sadgi pe kaun na mar jae ai KHuda laDte hain aur hath mein talwar bhi nahin
# mohabbat meñ nahīñ hai farq jiine aur marne kā usī ko dekh kar jiite haiñ jis kāfir pe dam nikle
# mohabbat mein nahin hai farq jine aur marne ka usi ko dekh kar jite hain jis kafir pe dam nikle
# hazāroñ ḳhvāhisheñ aisī ki har ḳhvāhish pe dam nikle bahut nikle mire armān lekin phir bhī kam nikle
# hazaron KHwahishen aisi ki har KHwahish pe dam nikle bahut nikle mere arman lekin phir bhi kam nikle
# un ke dekhe se jo aa jaatī hai muñh par raunaq vo samajhte haiñ ki bīmār kā haal achchhā hai
# ...

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'shayari': df})

# %%
df1
# Out:
#                                                shayari
# 0    ham ko ma.alūm hai jannat kī haqīqat lekin dil...
# 1    hum ko malum hai jannat ki haqiqat lekin dil k...
# 2    ishq ne 'ġhālib' nikammā kar diyā varna ham bh...
# 3    ishq ne 'ghaalib' nikamma kar diya warna hum b...
# 4    is sādgī pe kaun na mar jaa.e ai ḳhudā laḌte h...
# ..                                                 ...
# 734  kyuuñ na Thahreñ hadaf-e-nāvak-e-be-dād ki ham...
# 735  kyun na Thahren hadaf-e-nawak-e-be-dad ki hum ...
# 736  nisyah-o-naqd-e-do-ālam kī haqīqat mālūm le li...
# 737  nisyah-o-naqd-e-do-alam ki haqiqat malum le li...
# 738  ایک ایک قطرے کا مجھے دینا پڑا حساب خون جگر ودی...
#
# [739 rows x 1 columns]

# %%
df1["shayar"] = "ghalib"
df1
# Out:
#                                                shayari  shayar
# 0    ham ko ma.alūm hai jannat kī haqīqat lekin dil...  ghalib
# 1    hum ko malum hai jannat ki haqiqat lekin dil k...  ghalib
# 2    ishq ne 'ġhālib' nikammā kar diyā varna ham bh...  ghalib
# 3    ishq ne 'ghaalib' nikamma kar diya warna hum b...  ghalib
# 4    is sādgī pe kaun na mar jaa.e ai ḳhudā laḌte h...  ghalib
# ..                                                 ...     ...
# 734  kyuuñ na Thahreñ hadaf-e-nāvak-e-be-dād ki ham...  ghalib
# 735  kyun na Thahren hadaf-e-nawak-e-be-dad ki hum ...  ghalib
# 736  nisyah-o-naqd-e-do-ālam kī haqīqat mālūm le li...  ghalib
# 737  nisyah-o-naqd-e-do-alam ki haqiqat malum le li...  ghalib
# 738  ایک ایک قطرے کا مجھے دینا پڑا حساب خون جگر ودی...  ghalib
#
# [739 rows x 2 columns]

# %%
df1.to_csv('/Users/govindmittal/Downloads/shayari_data.csv', index=True)

# %%
#print(all_divs)

# %%
#url of the ghazal page we want to scrape
url = "https://www.rekhta.org/poets/mirza-ghalib/ghazals"
url1 = "https://www.rekhta.org/PoetCollection?lang=1&pageNumber=2&info=ghazals&SEO_Slug=ghazals&Id=c5097803-df0b-44eb-91fc-b20413837614&Info=ghazal&StartsWith=a&typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&keyword=&contentType=ghazals&sort=year-asc&filter=&_=1653761183808"
url2 = "https://www.rekhta.org/PoetCollection?lang=1&pageNumber=3&info=ghazals&SEO_Slug=ghazals&Id=c5097803-df0b-44eb-91fc-b20413837614&Info=ghazal&StartsWith=a&typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&keyword=&contentType=ghazals&sort=year-asc&filter=&_=1653761183809"
url3 = "https://www.rekhta.org/PoetCollection?lang=1&pageNumber=4&info=ghazals&SEO_Slug=ghazals&Id=c5097803-df0b-44eb-91fc-b20413837614&Info=ghazal&StartsWith=a&typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&keyword=&contentType=ghazals&sort=year-asc&filter=&_=1653761183810"
url4 = "https://www.rekhta.org/PoetCollection?lang=1&pageNumber=5&info=ghazals&SEO_Slug=ghazals&Id=c5097803-df0b-44eb-91fc-b20413837614&Info=ghazal&StartsWith=a&typeID=659186cb-44e7-4d94-8b1a-fc70f939a733&keyword=&contentType=ghazals&sort=year-asc&filter=&_=1653761183811"
# initiating the webdriver. Parameter includes the path of the webdriver.
driver = webdriver.Chrome('/Users/govindmittal/Downloads/chromedriver') 


driver.get(url) 
time.sleep(5) 
  
html = driver.page_source
driver.get(url1)
html1 = driver.page_source
driver.get(url2)
html2 = driver.page_source
driver.get(url3)
html3 = driver.page_source
driver.get(url4)
html4 = driver.page_source


  
# this renders the JS code and stores all
# of the information in static HTML code.
  
# Now, we could simply apply bs4 to html variable
soup = BeautifulSoup(html, "html.parser")
soup1 = BeautifulSoup(html1, "html.parser")
soup2 = BeautifulSoup(html2, "html.parser")
soup3 = BeautifulSoup(html3, "html.parser")
soup4 = BeautifulSoup(html4, "html.parser")
# Out:
# /var/folders/8w/h9y580gd7y55yx6l03k76n5c0000gn/T/ipykernel_7029/2600943824.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/govindmittal/Downloads/chromedriver')

# %%
soups = [soup,soup1,soup2,soup3,soup4]

# %%
page1 = soup.find_all("div", {'class' : "rt_bodyTitle"})

# %%
print(page1[0].text)
# Out:
# tum apne shikwe ki baaten na khod khod ke puchho

# %%
print(page1[0].h3)
# Out:
# <h3 class="noPoetSubTtl">tum apne shikwe ki baaten na khod khod ke puchho</h3>

# %%
refs = soup.find_all("a", {'class' : "contentListItemsMediaVideo rico-youtube"})

print(refs[0].get("href"))
# Out:
# https://www.rekhta.org/ghazals/kaar-gaah-e-hastii-men-laala-daag-saamaan-hai-mirza-ghalib-ghazals

# %%
gf

# %%
gf = []
for i in soups:
    for k in i.find_all('div', {'class' : 'rt_bodyTitle'}):
        print(k.text)
        result = k.text
        gf.append(result)
# Out:
# tum apne shikwe ki baaten na khod khod ke puchho
#
#
#
#
#
# ohde se madh-e-naz ke bahar na aa saka
#
#
#
#
#
# simab-pusht garmi-e-aina de hai hum
#
#
#
#
#
# tapish se meri waqf-e-kashmakash har tar-e-bistar hai
#
#
#
#
#
# wusat-e-sai-e-karam dekh ki sar-ta-sar-e-KHak
#
#
#
#
#
# jada-e-rah KHur ko waqt-e-sham hai tar-e-shuaa
#
#
#
#
#
# KHatar hai rishta-e-ulfat rag-e-gardan na ho jawe
#
#
#
#
#
# kare hai baada tere lab se kasb-e-rang-e-farogh
#
#
#
#
#
# kar-gah-e-hasti mein lala dagh-saman hai
#
#
#
#
#
# na lewe gar KHas-e-jauhar tarawat sabza-e-KHat se
#
#
#
#
#
# za-bas-ki mashq-e-tamasha junun-alamat hai
#
#
#
#
#
# pa-ba-daman ho raha hun bas-ki main sahra-naward
#
#
#
#
#
# hujum-e-nala hairat aajiz-e-arz yak-afghan hai
#
#
#
#
#
# junun ki dast-giri kis se ho gar ho na uryani
#
#
#
#
#
# lab-e-isa ki jumbish karti hai gahwara-jumbani
#
#
#
#
#
# lab-e-KHushk dar-tishnagi-murdagan ka
#
#
#
#
#
# nikohish hai saza fariyaadi-e-be-dad-e-dilbar ki
#
#
#
#
#
# ...

# %%
len(gf)
# Out:
# 234

# %%
gf1 = pd.DataFrame({'gazal_names': gf})
gf1
# Out:
#                                            gazal_names
# 0    \n\n\ntum apne shikwe ki baaten na khod khod k...
# 1     \n\n\nohde se madh-e-naz ke bahar na aa saka\n\n
# 2        \n\n\nsimab-pusht garmi-e-aina de hai hum\n\n
# 3    \n\n\ntapish se meri waqf-e-kashmakash har tar...
# 4    \n\n\nwusat-e-sai-e-karam dekh ki sar-ta-sar-e...
# ..                                                 ...
# 229  \n\n\nkabe mein ja raha to na do tana kya kahe...
# 230              \n\n\nphir is andaz se bahaar aai\n\n
# 231  \n\n\nnahin ki mujhko qayamat ka etiqad nahin\n\n
# 232  \n\n\nbahut sahi gham-e-giti sharab kam kya ha...
# 233       \n\n\nkyunkar us but se rakhun jaan aziz\n\n
#
# [234 rows x 1 columns]

# %%
gf1.replace(to_replace=["\n\n\n"], value=[""], regex=True, inplace=True)

# %%
gf1
# Out:
#                                            gazal_names
# 0    tum apne shikwe ki baaten na khod khod ke puch...
# 1           ohde se madh-e-naz ke bahar na aa saka\n\n
# 2              simab-pusht garmi-e-aina de hai hum\n\n
# 3    tapish se meri waqf-e-kashmakash har tar-e-bis...
# 4    wusat-e-sai-e-karam dekh ki sar-ta-sar-e-KHak\n\n
# ..                                                 ...
# 229      kabe mein ja raha to na do tana kya kahen\n\n
# 230                    phir is andaz se bahaar aai\n\n
# 231        nahin ki mujhko qayamat ka etiqad nahin\n\n
# 232      bahut sahi gham-e-giti sharab kam kya hai\n\n
# 233             kyunkar us but se rakhun jaan aziz\n\n
#
# [234 rows x 1 columns]

# %%
gf1.replace(to_replace=["\n\n"], value=[""], regex=True, inplace=True)
gf1
# Out:
#                                            gazal_names
# 0     tum apne shikwe ki baaten na khod khod ke puchho
# 1               ohde se madh-e-naz ke bahar na aa saka
# 2                  simab-pusht garmi-e-aina de hai hum
# 3    tapish se meri waqf-e-kashmakash har tar-e-bis...
# 4        wusat-e-sai-e-karam dekh ki sar-ta-sar-e-KHak
# ..                                                 ...
# 229          kabe mein ja raha to na do tana kya kahen
# 230                        phir is andaz se bahaar aai
# 231            nahin ki mujhko qayamat ka etiqad nahin
# 232          bahut sahi gham-e-giti sharab kam kya hai
# 233                 kyunkar us but se rakhun jaan aziz
#
# [234 rows x 1 columns]

# %%
gf1["gazal_names"][0]
# Out:
# 'tum apne shikwe ki baaten na khod khod ke puchho'

# %%
divs = soup.find_all('div', {'class' : 'rt_bodyTitle'})
link = divs[20].find_all('a', href = True)
link[0].get('href')
# Out:
# 'https://www.rekhta.org/ghazals/mastii-ba-zauq-e-gaflat-e-saaqii-halaak-hai-mirza-ghalib-ghazals'

# %%
link[0]['href']
# Out:
# 'https://www.rekhta.org/ghazals/mastii-ba-zauq-e-gaflat-e-saaqii-halaak-hai-mirza-ghalib-ghazals'

# %%
glinks = []
for soup in soups:
    divs = soup.find_all('div', {'class' : 'rt_bodyTitle'})
    for i in range(50):
        link = divs[i].find_all('a', href = True)
        result = link[0].get('href')
        print(result)
        glinks.append(result)
# Out:
# https://www.rekhta.org/ghazals/tum-apne-shikve-kii-baaten-na-khod-khod-ke-puuchho-mirza-ghalib-ghazals
# https://www.rekhta.org/ghazals/ohde-se-madh-e-naaz-ke-baahar-na-aa-sakaa-mirza-ghalib-ghazals
# https://www.rekhta.org/ghazals/siimaab-pusht-garmi-e-aaiina-de-hai-ham-mirza-ghalib-ghazals
# https://www.rekhta.org/ghazals/tapish-se-merii-vaqf-e-kashmakash-har-taar-e-bistar-hai-mirza-ghalib-ghazals
# https://www.rekhta.org/ghazals/vusat-e-sai-e-karam-dekh-ki-sar-taa-sar-e-khaak-mirza-ghalib-ghazals
# https://www.rekhta.org/ghazals/jaada-e-rah-khur-ko-vaqt-e-shaam-hai-taar-e-shuaaa-mirza-ghalib-ghazals
# https://www.rekhta.org/ghazals/khatar-hai-rishta-e-ulfat-rag-e-gardan-na-ho-jaave-mirza-ghalib-ghazals
# https://www.rekhta.org/ghazals/kare-hai-baada-tire-lab-se-kasb-e-rang-e-farog-mirza-ghalib-ghazals
# https://www.rekhta.org/ghazals/kaar-gaah-e-hastii-men-laala-daag-saamaan-hai-mirza-ghalib-ghazals
# ...

# %%
refs = []
for divs in soup.find_all('div', {'class' : 'rt_bodyTitle'}):
    
    try:    
        for i in div:
    except KeyError: 
            print 'ERROR: key not found!
                link = divs[i].find_all('a', href = True)
                print(link[0].get('href'))
                result = link[0].get('href')
                refs.append(result)
            
    
#print(k.find('a')['href'])
 #           result = k.find('a')['href']
  #          refs.append(result)
# Out:
#   Input In [168]
#     except KeyError:
#     ^
# IndentationError: expected an indented block

# %%
len(glinks)
# Out:
# 234

# %%
gf1["gazal_links"] = glinks
gf1
# Out:
#                                            gazal_names  \
# 0     tum apne shikwe ki baaten na khod khod ke puchho
# 1               ohde se madh-e-naz ke bahar na aa saka
# 2                  simab-pusht garmi-e-aina de hai hum
# 3    tapish se meri waqf-e-kashmakash har tar-e-bis...
# 4        wusat-e-sai-e-karam dekh ki sar-ta-sar-e-KHak
# ..                                                 ...
# 229          kabe mein ja raha to na do tana kya kahen
# 230                        phir is andaz se bahaar aai
# 231            nahin ki mujhko qayamat ka etiqad nahin
# 232          bahut sahi gham-e-giti sharab kam kya hai
# 233                 kyunkar us but se rakhun jaan aziz
#
#                                            gazal_links
# 0    https://www.rekhta.org/ghazals/tum-apne-shikve...
# 1    https://www.rekhta.org/ghazals/ohde-se-madh-e-...
# 2    https://www.rekhta.org/ghazals/siimaab-pusht-g...
# 3    https://www.rekhta.org/ghazals/tapish-se-merii...
# ...

# %%
page = requests.get('https://www.rekhta.org/ghazals/tum-apne-shikve-kii-baaten-na-khod-khod-ke-puuchho-mirza-ghalib-ghazals')
soup = BeautifulSoup(page, "html.parser")
divs = soup.find_all('div', {'class' : 'c'})
len(divs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [213], in <cell line: 2>()
#       1 page=requests.get('https://www.rekhta.org/ghazals/tum-apne-shikve-kii-baaten-na-khod-khod-ke-puuchho-mirza-ghalib-ghazals')
# ----> 2 soup = BeautifulSoup(page, "html.parser")
#       3 divs = soup.find_all('div', {'class' : 'c'})
#       4 len(divs)
#
# File ~/datascience-setup/env/lib/python3.8/site-packages/bs4/__init__.py:313, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     311 if hasattr(markup, 'read'):        # It's a file-type object.
#     312     markup = markup.read()
# --> 313 elif len(markup) <= 256 and (
#     314         (isinstance(markup, bytes) and not b'<' in markup)
#     315         or (isinstance(markup, str) and not '<' in markup)
#     316 ):
# ...

# %%
driver = webdriver.Chrome('/Users/govindmittal/Downloads/chromedriver')
# Out:
# /var/folders/8w/h9y580gd7y55yx6l03k76n5c0000gn/T/ipykernel_7029/3793949598.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/govindmittal/Downloads/chromedriver')

# %%
gf1
# Out:
#                                            gazal_names  \
# 0     tum apne shikwe ki baaten na khod khod ke puchho
# 1               ohde se madh-e-naz ke bahar na aa saka
# 2                  simab-pusht garmi-e-aina de hai hum
# 3    tapish se meri waqf-e-kashmakash har tar-e-bis...
# 4        wusat-e-sai-e-karam dekh ki sar-ta-sar-e-KHak
# ..                                                 ...
# 229          kabe mein ja raha to na do tana kya kahen
# 230                        phir is andaz se bahaar aai
# 231            nahin ki mujhko qayamat ka etiqad nahin
# 232          bahut sahi gham-e-giti sharab kam kya hai
# 233                 kyunkar us but se rakhun jaan aziz
#
#                                            gazal_links
# 0    https://www.rekhta.org/ghazals/tum-apne-shikve...
# 1    https://www.rekhta.org/ghazals/ohde-se-madh-e-...
# 2    https://www.rekhta.org/ghazals/siimaab-pusht-g...
# 3    https://www.rekhta.org/ghazals/tapish-se-merii...
# ...

# %%
gf1.to_csv('/Users/govindmittal/Downloads/ghazals_data.csv', index=False)

# %%
driver.get("https://www.rekhta.org/ghazals/kii-vafaa-ham-se-to-gair-is-ko-jafaa-kahte-hain-mirza-ghalib-ghazals") 
time.sleep(1) 
html = driver.page_source
#result = driver.find_elements_by_css_selector(".c span , #content p:nth-child(1)")
#result = driver.find_elements_by_class_name("c")
#result = driver.find_element(by=By.CSS_SELECTOR, value = ".c")
#page=requests.get(i)
soup = BeautifulSoup(html, "html.parser")
div = soup.find_all('div', {'class' : 'c'})
#div = soup.find_all('div', {'class' : 'c'})
#result = div[1].text
print(result)
# Out:
# aaj ham apnī pareshāni-e-ḳhātir un se kahne jaate to haiñ par dekhiye kyā kahte haiñ

# %%
len(div)
# Out:
# 18

# %%
gazal = ""
for i in range(len(div)) :
    text = div[i].text
    gazal = gazal+text
    i += 1
print(gazal)
# Out:
# kī vafā ham se to ġhair is ko jafā kahte haiñ hotī aa.ī hai ki achchhoñ ko burā kahte haiñ aaj ham apnī pareshāni-e-ḳhātir un se kahne jaate to haiñ par dekhiye kyā kahte haiñ agle vaqtoñ ke haiñ ye log inheñ kuchh na kaho jo mai o naġhma ko andoh-rubā kahte haiñ dil meñ aa jaa.e hai hotī hai jo fursat ġhash se aur phir kaun se naale ko rasā kahte haiñ hai par-e-sarhad-e-idrāk se apnā masjūd qible ko ahl-e-nazar qibla-numā kahte haiñ pā-e-afgār pe jab se tujhe rahm aayā hai ḳhār-e-rah ko tire ham mehr-e-giyā kahte haiñ ik sharar dil meñ hai us se koī ghabrā.egā kyā aag matlūb hai ham ko jo havā kahte haiñ dekhiye laatī hai us shoḳh kī naḳhvat kyā rañg us kī har baat pe ham nām-e-ḳhudā kahte haiñ 'vahshat' o 'sheftā' ab marsiya kahveñ shāyad mar gayā 'ġhālib'-e-āshufta-navā kahte haiñ ki wafa hum se to ghair is ko jafa kahte hain hoti aai hai ki achchhon ko bura kahte hain aaj hum apni pareshani-e-KHatir un se kahne jate to hain par dekhiye kya kahte hain agle waqton ke hain ye log in
# ...

# %%
gazals = []

# %%
driver = webdriver.Chrome('/Users/govindmittal/Downloads/chromedriver')
# Out:
# /var/folders/8w/h9y580gd7y55yx6l03k76n5c0000gn/T/ipykernel_7029/697151179.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/govindmittal/Downloads/chromedriver')

# %%
for i in range(150,234):
    driver.get(gf1["gazal_links"][i])
    time.sleep(1) 
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    div = soup.find_all('div', {'class' : 'c'})
    gazal = ""
    for k in range(len(div)) :
        text = div[k].text
        gazal = gazal+text
        i+=1
    gazals.append(gazal)
        
    #gazals[i] = gazal 
print(gazals)
# Out:
# ["tum apne shikve kī bāteñ na khod khod ke pūchho hazar karo mire dil se ki is meñ aag dabī hai dilā ye dard-o-alam bhī to muġhtanim hai ki āḳhir na girya-e-saharī hai na āh-e-nīm-shabī hai nazar ba-naqs-e-gadāyāñ kamāl-e-be-adabī hai ki ḳhār-e-ḳhushk ko bhī dāvā-e-chaman-nasabī hai Interestinghuā visāl se shauq-e-dil-e-harīs ziyāda lab-e-qadah pe kaf-e-bāda josh-e-tishna-labī hai ḳhushā vo dil ki sarāpā tilism-e-be-ḳhabarī ho junūn o yaas o alam rizq-e-mudda.ā-talabī hai chaman meñ kis ke ye barham hui hai bazm-e-tamāshā ki barg barg-e-saman shīsha reza-e-halabī hai imām-e-zāhir-o-bātin amīr-e-sūrat-o-ma.anī 'alī' valī asadullāh jānashīn-e-nabī hai tum apne shikwe ki baaten na khod khod ke puchho hazar karo mere dil se ki is mein aag dabi hai dila ye dard-o-alam bhi to mughtanim hai ki aaKHir na girya-e-sahari hai na aah-e-nim-shabi hai nazar ba-naqs-e-gadayan kamal-e-be-adabi hai ki KHar-e-KHushk ko bhi dawa-e-chaman-nasabi hai Interestinghua visal se shauq-e-dil-e-haris ziyaada la
# ...

# %%
len(gazals)
# Out:
# 234

# %%
gf1["gazals"] = gazals

# %%
gf1
# Out:
#                                            gazal_names  \
# 0     tum apne shikwe ki baaten na khod khod ke puchho
# 1               ohde se madh-e-naz ke bahar na aa saka
# 2                  simab-pusht garmi-e-aina de hai hum
# 3    tapish se meri waqf-e-kashmakash har tar-e-bis...
# 4        wusat-e-sai-e-karam dekh ki sar-ta-sar-e-KHak
# ..                                                 ...
# 229          kabe mein ja raha to na do tana kya kahen
# 230                        phir is andaz se bahaar aai
# 231            nahin ki mujhko qayamat ka etiqad nahin
# 232          bahut sahi gham-e-giti sharab kam kya hai
# 233                 kyunkar us but se rakhun jaan aziz
#
#                                            gazal_links  \
# 0    https://www.rekhta.org/ghazals/tum-apne-shikve...
# 1    https://www.rekhta.org/ghazals/ohde-se-madh-e-...
# 2    https://www.rekhta.org/ghazals/siimaab-pusht-g...
# 3    https://www.rekhta.org/ghazals/tapish-se-merii...
# ...

# %%
len(gf1["gazal_links"])
# Out:
# 234

# %%
gf1["gazals"][0]
# Out:
# "tum apne shikve kī bāteñ na khod khod ke pūchho hazar karo mire dil se ki is meñ aag dabī hai dilā ye dard-o-alam bhī to muġhtanim hai ki āḳhir na girya-e-saharī hai na āh-e-nīm-shabī hai nazar ba-naqs-e-gadāyāñ kamāl-e-be-adabī hai ki ḳhār-e-ḳhushk ko bhī dāvā-e-chaman-nasabī hai Interestinghuā visāl se shauq-e-dil-e-harīs ziyāda lab-e-qadah pe kaf-e-bāda josh-e-tishna-labī hai ḳhushā vo dil ki sarāpā tilism-e-be-ḳhabarī ho junūn o yaas o alam rizq-e-mudda.ā-talabī hai chaman meñ kis ke ye barham hui hai bazm-e-tamāshā ki barg barg-e-saman shīsha reza-e-halabī hai imām-e-zāhir-o-bātin amīr-e-sūrat-o-ma.anī 'alī' valī asadullāh jānashīn-e-nabī hai tum apne shikwe ki baaten na khod khod ke puchho hazar karo mere dil se ki is mein aag dabi hai dila ye dard-o-alam bhi to mughtanim hai ki aaKHir na girya-e-sahari hai na aah-e-nim-shabi hai nazar ba-naqs-e-gadayan kamal-e-be-adabi hai ki KHar-e-KHushk ko bhi dawa-e-chaman-nasabi hai Interestinghua visal se shauq-e-dil-e-haris ziyaada lab
# ...

# %%
gf1.to_csv('/Users/govindmittal/Downloads/ghazals_data.csv', index=False)

# %%
import pandas as pd

# %%
gf2 = pd.read_csv('/Users/govindmittal/Documents/data analysis/Datasets/ghazals_data.csv')
gf2
# Out:
#                                            instruction  \
# 0    you are an urdu/ hindi poet/shayar/kavi who wi...
# 1    you are an urdu/ hindi poet/shayar/kavi who wi...
# 2    you are an urdu/ hindi poet/shayar/kavi who wi...
# 3    you are an urdu/ hindi poet/shayar/kavi who wi...
# 4    you are an urdu/ hindi poet/shayar/kavi who wi...
# ..                                                 ...
# 229  you are an urdu/ hindi poet/shayar/kavi who wi...
# 230  you are an urdu/ hindi poet/shayar/kavi who wi...
# 231  you are an urdu/ hindi poet/shayar/kavi who wi...
# 232  you are an urdu/ hindi poet/shayar/kavi who wi...
# 233  you are an urdu/ hindi poet/shayar/kavi who wi...
#
#                                                  input  \
# 0     tum apne shikwe ki baaten na khod khod ke puchho
# 1               ohde se madh-e-naz ke bahar na aa saka
# 2                  simab-pusht garmi-e-aina de hai hum
# 3    tapish se meri waqf-e-kashmakash har tar-e-bis...
# ...

# %%
gf2.output[0]
# Out:
# "tum apne shikve kī bāteñ na khod khod ke pūchho hazar karo mire dil se ki is meñ aag dabī hai dilā ye dard-o-alam bhī to muġhtanim hai ki āḳhir na girya-e-saharī hai na āh-e-nīm-shabī hai nazar ba-naqs-e-gadāyāñ kamāl-e-be-adabī hai ki ḳhār-e-ḳhushk ko bhī dāvā-e-chaman-nasabī hai Interestinghuā visāl se shauq-e-dil-e-harīs ziyāda lab-e-qadah pe kaf-e-bāda josh-e-tishna-labī hai ḳhushā vo dil ki sarāpā tilism-e-be-ḳhabarī ho junūn o yaas o alam rizq-e-mudda.ā-talabī hai chaman meñ kis ke ye barham hui hai bazm-e-tamāshā ki barg barg-e-saman shīsha reza-e-halabī hai imām-e-zāhir-o-bātin amīr-e-sūrat-o-ma.anī 'alī' valī asadullāh jānashīn-e-nabī hai tum apne shikwe ki baaten na khod khod ke puchho hazar karo mere dil se ki is mein aag dabi hai dila ye dard-o-alam bhi to mughtanim hai ki aaKHir na girya-e-sahari hai na aah-e-nim-shabi hai nazar ba-naqs-e-gadayan kamal-e-be-adabi hai ki KHar-e-KHushk ko bhi dawa-e-chaman-nasabi hai Interestinghua visal se shauq-e-dil-e-haris ziyaada lab
# ...

# %%
f2 = pd.read_csv('/Users/govindmittal/Downloads/train_ghazals.csv')
f2
# Out:
#                                            instruction  \
# 0    you are an urdu/hindi shayar/kavi/poet and you...
# 1    you are an urdu/hindi shayar/kavi/poet and you...
# 2    you are an urdu/hindi shayar/kavi/poet and you...
# 3    you are an urdu/hindi shayar/kavi/poet and you...
# 4    you are an urdu/hindi shayar/kavi/poet and you...
# ..                                                 ...
# 204  you are an urdu/hindi shayar/kavi/poet and you...
# 205  you are an urdu/hindi shayar/kavi/poet and you...
# 206  you are an urdu/hindi shayar/kavi/poet and you...
# 207  you are an urdu/hindi shayar/kavi/poet and you...
# 208  you are an urdu/hindi shayar/kavi/poet and you...
#
#                                                  input  \
# 0     tum apne shikwe ki baaten na khod khod ke puchho
# 1               ohde se madh-e-naz ke bahar na aa saka
# 2                  simab-pusht garmi-e-aina de hai hum
# 3    tapish se meri waqf-e-kashmakash har tar-e-bis...
# ...
